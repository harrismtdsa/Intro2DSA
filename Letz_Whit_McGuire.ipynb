# %% [markdown]
# ## Linear Regression and Machine Learning

# %%
import pandas
cost = pandas.read_excel('id_cost.xlsx')
data = pandas.read_excel('id_data.xlsx')

# %%
datacost=cost.merge(data,on='Id')
datacost.sort_values('SalePrice')[0:5]
# Out:
#         Id    SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 1140  2601  135751.3189         120       RM         62.0     6710   Pave
# 1449  2910  137402.5699         180       RM         21.0     1470   Pave
# 138   1599  138607.9715         120       RM         35.0     3907   Pave
# 280   1741  139010.8478         120       FV          NaN     4217   Pave
# 784   2245  139169.8664         180       RM         21.0     1596   Pave
#
#      Alley LotShape LandContour      ...       ScreenPorch PoolArea PoolQC  \
# 1140   NaN      IR1         Lvl      ...                 0        0    NaN
# 1449   NaN      Reg         Lvl      ...                 0        0    NaN
# 138    NaN      IR1         HLS      ...                 0        0    NaN
# 280   Pave      IR1         Lvl      ...                 0        0    NaN
# 784    NaN      Reg         Lvl      ...                 0        0    NaN
#
#      Fence MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition
# ...

# %%
datacost.sort_values('LotArea')[0:5]
# Out:
#         Id    SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 1449  2910  137402.5699         180       RM         21.0     1470   Pave
# 154   1615  159270.5378         160       RM         21.0     1476   Pave
# 786   2247  161067.8598         160       RM         21.0     1477   Pave
# 1450  2911  165086.7751         160       RM         21.0     1484   Pave
# 448   1909  154650.1990         160       RM         24.0     1488   Pave
#
#      Alley LotShape LandContour      ...       ScreenPorch PoolArea PoolQC  \
# 1449   NaN      Reg         Lvl      ...                 0        0    NaN
# 154    NaN      Reg         Lvl      ...                 0        0    NaN
# 786    NaN      Reg         Lvl      ...                 0        0    NaN
# 1450   NaN      Reg         Lvl      ...                 0        0    NaN
# 448    NaN      Reg         Lvl      ...                 0        0    NaN
#
# ...

# %%
datacost.loc[datacost['LotArea'].idxmax()]
# Out:
# Id                  2251
# SalePrice         280618
# MSSubClass            70
# MSZoning             NaN
# LotFrontage          NaN
# LotArea            56600
# Street              Pave
# Alley                NaN
# LotShape             IR1
# LandContour          Low
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood      IDOTRR
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        2.5Unf
# OverallQual            5
# OverallCond            1
# YearBuilt           1900
# YearRemodAdd        1950
# RoofStyle            Hip
# RoofMatl         CompShg
# Exterior1st      Wd Sdng
# Exterior2nd      Wd Sdng
# MasVnrType          None
# MasVnrArea             0
# ExterQual             TA
# ExterCond             TA
#                   ...
# HalfBath               0
# BedroomAbvGr           4
# KitchenAbvGr           1
# KitchenQual           TA
# TotRmsAbvGrd           7
# Functional          Maj1
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4)) #changes figure size
plt.plot(datacost['LotArea'],datacost['SalePrice'],'b.', alpha=0.1)
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">

# %%
plt.figure(figsize=(8,4)) #changes figure size
plt.plot(datacost['LotArea'],datacost['SalePrice'],'b.', alpha=0.1)
plt.xlim(0,20000) #limits the x axis
plt.ylim(130000,280000) #limits the y axis
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">
# (130000, 280000)

# %%
datacost.sort_values('LotArea').head()
# Out:
#         Id    SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 1449  2910  137402.5699         180       RM         21.0     1470   Pave
# 154   1615  159270.5378         160       RM         21.0     1476   Pave
# 786   2247  161067.8598         160       RM         21.0     1477   Pave
# 1450  2911  165086.7751         160       RM         21.0     1484   Pave
# 448   1909  154650.1990         160       RM         24.0     1488   Pave
#
#      Alley LotShape LandContour      ...       ScreenPorch PoolArea PoolQC  \
# 1449   NaN      Reg         Lvl      ...                 0        0    NaN
# 154    NaN      Reg         Lvl      ...                 0        0    NaN
# 786    NaN      Reg         Lvl      ...                 0        0    NaN
# 1450   NaN      Reg         Lvl      ...                 0        0    NaN
# 448    NaN      Reg         Lvl      ...                 0        0    NaN
#
# ...

# %% [markdown]
# np.array[lotarea] can use more than one variable [var 1 separated by comma,][var 2 sep by comm], [b]
# np.array[x,b]

# %%
a=datacost['LotArea'].values
b=datacost['SalePrice'].values
x=np.array(a) #array of all x-values/features (Lot Area)
y=np.array(b) #array of all y-values/labels (Sale Price)
l=len(datacost) #definited l as the length of the dataframe small

# %%
bee=np.ones(l) #makes an array of all ones for as many items as are in the dataframe small

# %%
bee
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %% [markdown]
# y=w1x1 +w2x2....+b ls (w,x,y)
# array of all w's
# array of all x's
# array of all y's
# array of all b's [which is one]

# %%
#ls(w,x,y)
#y=wx+b

X=np.array([x,bee]).T #transpose of the array

# %%
X #[x-value, coefficient of b]
# Out:
# array([[1.1622e+04, 1.0000e+00],
#        [1.4267e+04, 1.0000e+00],
#        [1.3830e+04, 1.0000e+00],
#        ...,
#        [2.0000e+04, 1.0000e+00],
#        [1.0441e+04, 1.0000e+00],
#        [9.6270e+03, 1.0000e+00]])

# %%
slope_val = 0 #starting point for w
intercept = 155000
incr = .005 #increasing the slope by .005 with every pass through the loop
test_list_error = [[]] *500 #creates a list of the loss so that the minimum can be established
test_list_w = [[]] *500
loss = 0
def sales(w,X,y):
    return(np.sum((np.dot(X,w)-y)**2)/l) #.dot function [a,b,c] [d,e,f]=ad+be+cf

for index in range(len(test_list_error)):
 
 slope_val = slope_val + incr
 w=np.array([slope_val,intercept]) #[w-value, b-value]
 loss = sales(w,X,y)
 
 print("Error:",sales(w,X,y), "W =",incr)
 test_list_w[index] = incr
 incr = incr + .005
 test_list_error[index] = loss


print(min(test_list_error))
defg = test_list_error.index(min(test_list_error))
print(test_list_w[defg])

#print(test_list_w.index[indexer])

#print(min(test_list_w))
    
    
 

#print(min(test_list))
# Out:
# Error: 854572063.5334597 W = 0.005
# Error: 848675888.7537074 W = 0.01
# Error: 839876985.1757987 W = 0.015
# Error: 828229783.1097966 W = 0.02
# Error: 813806856.3024528 W = 0.025
# Error: 796698921.9372058 W = 0.030000000000000002
# Error: 777014840.6341827 W = 0.035
# Error: 754881616.4501978 W = 0.04
# Error: 730444396.8787539 W = 0.045
# Error: 703866472.8500409 W = 0.049999999999999996
# Error: 675329278.730937 W = 0.05499999999999999
# Error: 645032392.3250079 W = 0.05999999999999999
# Error: 613193534.8725071 W = 0.06499999999999999
# Error: 580048571.0503762 W = 0.06999999999999999
# Error: 545851508.9722441 W = 0.075
# Error: 510874500.1884282 W = 0.08
# Error: 475407839.68593305 W = 0.085
# Error: 439759965.88845116 W = 0.09000000000000001
# Error: 404257460.6563631 W = 0.09500000000000001
# Error: 369245049.2867371 W = 0.10000000000000002
# Error: 335085600.5133291 W = 0.10500000000000002
# Error: 302160126.50658274 W = 0.11000000000000003
# ...

# %% [markdown]
# Based on these figures, we have an error of 133,207,734.  Our formula here would be y=0.155x+155000

# %%
slope_val = 0 #starting point for w
intercept = 155000 # At this point, we will leave this the same to more accurately adjust the slope.
incr = .005 #increasing the slope by .005 with every pass through the loop
incr_rate = .005
test_list_error = [[]] *10000 #creates a list of the loss so that the minimum can be established
test_list_w = [[]] *10000
loss = 0
def sales(w,X,y):
    return(np.sum((np.dot(X,w)-y)**2)/l) #.dot function [a,b,c] [d,e,f]=ad+be+cf

for index in range(len(test_list_error)):
 
 slope_val = slope_val + incr #running sales with a different slope each time - increasing by the incr_rate
 w=np.array([slope_val,intercept]) #array of [w-value, b-value]
 loss = sales(w,X,y) #provides the 
 
 print("Error:",sales(w,X,y), "W =",slope_val)
 test_list_w[index] = slope_val
 test_list_error[index] = loss


print(min(test_list_error))
defg = test_list_error.index(min(test_list_error))
print(test_list_w[defg])
# Out:
# Error: 854572063.5334597 W = 0.005
# Error: 851620952.2374688 W = 0.01
# Error: 848675888.7537074 W = 0.015
# Error: 845736873.0821754 W = 0.02
# Error: 842803905.2228725 W = 0.025
# Error: 839876985.1757987 W = 0.030000000000000002
# Error: 836956112.9409543 W = 0.035
# Error: 834041288.5183392 W = 0.04
# Error: 831132511.9079535 W = 0.045
# Error: 828229783.1097966 W = 0.049999999999999996
# Error: 825333102.1238695 W = 0.05499999999999999
# Error: 822442468.9501712 W = 0.05999999999999999
# Error: 819557883.5887026 W = 0.06499999999999999
# Error: 816679346.039463 W = 0.06999999999999999
# Error: 813806856.3024528 W = 0.075
# Error: 810940414.3776718 W = 0.08
# Error: 808080020.26512 W = 0.085
# Error: 805225673.9647976 W = 0.09000000000000001
# Error: 802377375.4767042 W = 0.09500000000000001
# Error: 799535124.8008405 W = 0.10000000000000002
# Error: 796698921.9372058 W = 0.10500000000000002
# Error: 793868766.8858004 W = 0.11000000000000003
# ...

# %%
sl=2.44
interc=155000
plt.figure(figsize=(8,4)) #changes figure size
plt.plot(datacost['LotArea'],datacost['SalePrice'],'b.', alpha=0.1)
plt.plot([0,60000],[interc,60000*sl+interc])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">

# %%
sl=2.44
interc=155000
plt.figure(figsize=(8,4)) #changes figure size
plt.plot([0,60000],[interc,60000*sl+interc])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">
